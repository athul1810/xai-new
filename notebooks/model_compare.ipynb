# %% [markdown]
# # Model Comparison
# its
# Compare model metrics and visualize SHAP explanations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load metrics
metrics_df = pd.read_csv('../outputs/metrics.csv')
print(metrics_df)
